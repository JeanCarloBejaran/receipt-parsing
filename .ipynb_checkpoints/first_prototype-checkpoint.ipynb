# %%
import boto3
import pandas as pd
import dateutil
import re

# %%
import boto3

# Document
s3BucketName = "receipt-parsing-mvp"
documentName = "recibo5.jpg"

# Amazon Textract client
textract = boto3.client('textract')

# Call Amazon Textract — DETECT DOCUMENT TEXT
# response = textract.detect_document_text(
#     Document={
#         'S3Object': {
#             'Bucket': s3BucketName,
#             'Name': documentName
#         }
#     })

# Call Amazon Textract — ANALYZE DOCUMENT
response = textract.analyze_document(
    Document={
        'S3Object': {
            'Bucket': s3BucketName,
            'Name': documentName
        }
    },
    FeatureTypes=["FORMS"])

# %%
blocks = response["Blocks"]
len(blocks)
# Out:
# 271

# %%
df = pd.DataFrame(blocks)
df.head(4)
# Out:
#   BlockType                                           Geometry  \
# 0      PAGE  {'BoundingBox': {'Width': 1.0, 'Height': 1.0, ...
# 1      LINE  {'BoundingBox': {'Width': 0.10197052359580994,...
# 2      LINE  {'BoundingBox': {'Width': 0.2641707956790924, ...
# 3      LINE  {'BoundingBox': {'Width': 0.3089200556278229, ...
#
#                                      Id  \
# 0  fe9a50b5-87d2-44eb-a5a9-a8c57a227c9f
# 1  72d9d33e-1937-4e90-8445-985c41ecf265
# 2  03115951-50bc-48d4-af49-1d6ee1ba52e5
# 3  7ce91950-e374-4837-ad80-f294f5cc5737
#
#                                        Relationships  Confidence  \
# 0  [{'Type': 'CHILD', 'Ids': ['72d9d33e-1937-4e90...         NaN
# 1  [{'Type': 'CHILD', 'Ids': ['aa22dd4e-8331-408a...   42.197727
# 2  [{'Type': 'CHILD', 'Ids': ['03752ef0-e458-4ebb...   99.785187
# 3  [{'Type': 'CHILD', 'Ids': ['1f42f850-dee8-4f28...   87.803307
#
#                         Text EntityTypes
# 0                        NaN         NaN
# 1                          N         NaN
# 2  FACTURA DE CREDITO FISCAL         NaN
# 3      latienda de La fabric         NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271 entries, 0 to 270
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   BlockType      271 non-null    object
#  1   Geometry       271 non-null    object
#  2   Id             271 non-null    object
#  3   Relationships  89 non-null     object
#  4   Confidence     270 non-null    float64
#  5   Text           260 non-null    object
#  6   EntityTypes    10 non-null     object
# dtypes: float64(1), object(6)
# memory usage: 14.9+ KB

# %%
df.Confidence.describe()
# Out:
# count    270.000000
# mean      87.726435
# std       16.697092
# min       31.424656
# 25%       84.671217
# 50%       94.327225
# 75%       98.669889
# max       99.911316
# Name: Confidence, dtype: float64

# %%
df[df.Confidence < 50]
# Out:
#          BlockType                                           Geometry  \
# 1             LINE  {'BoundingBox': {'Width': 0.10197052359580994,...
# 76            LINE  {'BoundingBox': {'Width': 0.009968757629394531...
# 80            WORD  {'BoundingBox': {'Width': 0.10197052359580994,...
# 137           WORD  {'BoundingBox': {'Width': 0.01789657026529312,...
# 145           WORD  {'BoundingBox': {'Width': 0.016008170321583748...
# 156           WORD  {'BoundingBox': {'Width': 0.016011299565434456...
# 166           WORD  {'BoundingBox': {'Width': 0.01789340004324913,...
# 168           WORD  {'BoundingBox': {'Width': 0.04955479875206947,...
# 172           WORD  {'BoundingBox': {'Width': 0.010134919546544552...
# 194           WORD  {'BoundingBox': {'Width': 0.021167660132050514...
# 235           WORD  {'BoundingBox': {'Width': 0.009968739934265614...
# 263  KEY_VALUE_SET  {'BoundingBox': {'Width': 0.04558669030666351,...
# 264  KEY_VALUE_SET  {'BoundingBox': {'Width': 0.06969587504863739,...
# 265  KEY_VALUE_SET  {'BoundingBox': {'Width': 0.03189649432897568,...
# 266  KEY_VALUE_SET  {'BoundingBox': {'Width': 0.027426740154623985...
# 267  KEY_VALUE_SET  {'BoundingBox': {'Width': 0.06722420454025269,...
# 268  KEY_VALUE_SET  {'BoundingBox': {'Width': 0.08409015089273453,...
# 269  KEY_VALUE_SET  {'BoundingBox': {'Width': 0.02912968583405018,...
# 270  KEY_VALUE_SET  {'BoundingBox': {'Width': 0.07737024128437042,...
#
#                                        Id  \
# 1    72d9d33e-1937-4e90-8445-985c41ecf265
# 76   13d17c9d-aa99-453e-961f-678223add79c
# 80   aa22dd4e-8331-408a-ae59-2faf67778f39
# 137  df655d26-0fb6-4d73-8423-3c9285e741e4
# 145  dc76d88e-1b9e-4eeb-bff4-93e2cd76e2d2
# 156  83775a97-65cb-4976-a126-21ff861874fc
# 166  2cbf4ea6-b69f-4aea-b78a-5ce575a4f12e
# 168  40b5cd5f-58ed-44f8-a8a2-b832fc59dc65
# 172  12b109d4-06d4-4661-afd5-777480d29081
# 194  6f23c887-3a06-4ab5-b53a-7d261fbcd063
# 235  90ea2764-a4fe-4177-a3c6-66d9cc586700
# 263  58356817-dffc-4923-9280-df1cb805c193
# 264  d8d14938-22b0-414e-b280-eb72dc8232a3
# 265  c4ff3d80-3f25-47ac-8235-0a0fc49f8e77
# 266  8c0e46e0-9ed3-4243-9875-a6c754af25cf
# 267  e69be1c3-ba2b-43ca-8c04-958cf3bb0a5a
# 268  129f7918-8620-4d8d-84aa-fd99ae9b2673
# 269  2ee0e754-69a6-44b8-b348-eaa7b2021d48
# 270  a6e7fa2c-3eae-4af1-9cca-4355ab0c8376
#
#                                          Relationships  Confidence    Text  \
# 1    [{'Type': 'CHILD', 'Ids': ['aa22dd4e-8331-408a...   42.197727       N
# 76   [{'Type': 'CHILD', 'Ids': ['90ea2764-a4fe-4177...   33.110855       0
# 80                                                 NaN   42.197727       N
# 137                                                NaN   45.687588      ()
# 145                                                NaN   47.271072      NE
# 156                                                NaN   31.424656      C2
# 166                                                NaN   41.683704     0.1
# 168                                                NaN   34.040489  42x10A
# 172                                                NaN   34.962708       6
# 194                                                NaN   43.489273    20/1
# 235                                                NaN   33.110855       0
# 263  [{'Type': 'VALUE', 'Ids': ['d8d14938-22b0-414e...   47.854630     NaN
# 264  [{'Type': 'CHILD', 'Ids': ['0daf0717-5029-4669...   47.854630     NaN
# 265  [{'Type': 'VALUE', 'Ids': ['8c0e46e0-9ed3-4243...   41.732441     NaN
# 266  [{'Type': 'CHILD', 'Ids': ['42fea3d3-87f8-491e...   41.732441     NaN
# 267  [{'Type': 'VALUE', 'Ids': ['129f7918-8620-4d8d...   36.380848     NaN
# 268                                                NaN   36.380848     NaN
# 269  [{'Type': 'VALUE', 'Ids': ['a6e7fa2c-3eae-4af1...   40.831776     NaN
# 270  [{'Type': 'CHILD', 'Ids': ['0a1fcb21-1db5-4c77...   40.831776     NaN
#
#     EntityTypes
# 1           NaN
# 76          NaN
# 80          NaN
# 137         NaN
# 145         NaN
# 156         NaN
# 166         NaN
# 168         NaN
# 172         NaN
# 194         NaN
# 235         NaN
# 263       [KEY]
# 264     [VALUE]
# 265       [KEY]
# 266     [VALUE]
# 267       [KEY]
# 268     [VALUE]
# 269       [KEY]
# 270     [VALUE]

# %%
df.loc[df.BlockType == "LINE", "Text"][1]
# Out:
# 'N'

# %%
df[df.BlockType == "LINE"].head(50)
# Out:
#    BlockType                                           Geometry  \
# 1       LINE  {'BoundingBox': {'Width': 0.10197052359580994,...
# 2       LINE  {'BoundingBox': {'Width': 0.2641707956790924, ...
# 3       LINE  {'BoundingBox': {'Width': 0.3089200556278229, ...
# 4       LINE  {'BoundingBox': {'Width': 0.15606212615966797,...
# 5       LINE  {'BoundingBox': {'Width': 0.1537366360425949, ...
# 6       LINE  {'BoundingBox': {'Width': 0.23485486209392548,...
# 7       LINE  {'BoundingBox': {'Width': 0.18215829133987427,...
# 8       LINE  {'BoundingBox': {'Width': 0.12326973676681519,...
# 9       LINE  {'BoundingBox': {'Width': 0.12588292360305786,...
# 10      LINE  {'BoundingBox': {'Width': 0.2724972367286682, ...
# 11      LINE  {'BoundingBox': {'Width': 0.23673295974731445,...
# 12      LINE  {'BoundingBox': {'Width': 0.30636918544769287,...
# 13      LINE  {'BoundingBox': {'Width': 0.08871172368526459,...
# 14      LINE  {'BoundingBox': {'Width': 0.03050774335861206,...
# 15      LINE  {'BoundingBox': {'Width': 0.04700714349746704,...
# 16      LINE  {'BoundingBox': {'Width': 0.24806219339370728,...
# 17      LINE  {'BoundingBox': {'Width': 0.07802759110927582,...
# 18      LINE  {'BoundingBox': {'Width': 0.076575368642807, '...
# 19      LINE  {'BoundingBox': {'Width': 0.07149055600166321,...
# 20      LINE  {'BoundingBox': {'Width': 0.11754702031612396,...
# 21      LINE  {'BoundingBox': {'Width': 0.1758672147989273, ...
# 22      LINE  {'BoundingBox': {'Width': 0.08541113138198853,...
# 23      LINE  {'BoundingBox': {'Width': 0.047729313373565674...
# 24      LINE  {'BoundingBox': {'Width': 0.029622375965118408...
# 25      LINE  {'BoundingBox': {'Width': 0.06061840057373047,...
# 26      LINE  {'BoundingBox': {'Width': 0.042859651148319244...
# 27      LINE  {'BoundingBox': {'Width': 0.2097456455230713, ...
# 28      LINE  {'BoundingBox': {'Width': 0.009321048855781555...
# 29      LINE  {'BoundingBox': {'Width': 0.23781853914260864,...
# 30      LINE  {'BoundingBox': {'Width': 0.030563294887542725...
# 31      LINE  {'BoundingBox': {'Width': 0.03641575574874878,...
# 32      LINE  {'BoundingBox': {'Width': 0.04147937148809433,...
# 33      LINE  {'BoundingBox': {'Width': 0.25667890906333923,...
# 34      LINE  {'BoundingBox': {'Width': 0.024429142475128174...
# 35      LINE  {'BoundingBox': {'Width': 0.04490697383880615,...
# 36      LINE  {'BoundingBox': {'Width': 0.04107629507780075,...
# 37      LINE  {'BoundingBox': {'Width': 0.2180504947900772, ...
# 38      LINE  {'BoundingBox': {'Width': 0.030872702598571777...
# 39      LINE  {'BoundingBox': {'Width': 0.03619098663330078,...
# 40      LINE  {'BoundingBox': {'Width': 0.04128023982048035,...
# 41      LINE  {'BoundingBox': {'Width': 0.013444989919662476...
# 42      LINE  {'BoundingBox': {'Width': 0.1513173133134842, ...
# 40  f90ecf42-d134-4919-8717-7eac88663eab
# 41  31b098db-ecd7-4240-b046-9b39aca66564
# 42  c12f63f3-7def-4fb9-bf36-8197e3d058ff
# 43  9bb10e45-65d9-4c45-b0ee-8ecd62d844ee
# 44  b4dd6bbf-6124-419a-85a1-edd3f898106c
# 45  8492b910-2a44-42f1-be97-26d6800f713e
# 46  4a0d0c1b-a3d2-4c39-9d68-a6ccacb219f9
# 47  9e1d05db-e90f-43f1-bb0b-cbf579e74abb
# 48  61eb52bd-0c0a-46e3-8c65-98efbbef4ce6
# 49  d0aa17d1-c809-43f3-93bf-1ac3958a30a8
# 50  63c178d1-fa00-4b04-84c2-6721b1d73ff3
#
#                                         Relationships  Confidence  \
# 1   [{'Type': 'CHILD', 'Ids': ['aa22dd4e-8331-408a...   42.197727
# 2   [{'Type': 'CHILD', 'Ids': ['03752ef0-e458-4ebb...   99.785187
# 3   [{'Type': 'CHILD', 'Ids': ['1f42f850-dee8-4f28...   87.803307
# 4   [{'Type': 'CHILD', 'Ids': ['a892ccdc-93e8-41df...   97.813652
# 5   [{'Type': 'CHILD', 'Ids': ['a7d143a8-155a-4348...   98.697617
# 6   [{'Type': 'CHILD', 'Ids': ['6c0dff1c-f137-4d03...   96.307755
# 7   [{'Type': 'CHILD', 'Ids': ['775128de-8993-47f9...   96.210945
# 8   [{'Type': 'CHILD', 'Ids': ['43bb3a1c-8f25-497b...   99.683609
# 9   [{'Type': 'CHILD', 'Ids': ['cc2dd464-ce51-45d0...   96.052078
# 10  [{'Type': 'CHILD', 'Ids': ['d18c1cbd-9b5d-4765...   93.639687
# 11  [{'Type': 'CHILD', 'Ids': ['a2a995b0-9750-4168...   97.877777
# 12  [{'Type': 'CHILD', 'Ids': ['a458057a-c79d-4a1c...   99.585136
# 13  [{'Type': 'CHILD', 'Ids': ['539ea562-fc4c-44df...   80.174423
# 14  [{'Type': 'CHILD', 'Ids': ['2baadebd-62d4-4ce1...   99.132202
# 15  [{'Type': 'CHILD', 'Ids': ['c32df702-4ad1-44b5...   99.587479
# 16  [{'Type': 'CHILD', 'Ids': ['731f86f4-8efc-4d3a...   94.314804
# 17  [{'Type': 'CHILD', 'Ids': ['b5e3b466-6509-467a...   91.613976
# 18  [{'Type': 'CHILD', 'Ids': ['0a1fcb21-1db5-4c77...   98.497734
# 19  [{'Type': 'CHILD', 'Ids': ['0daf0717-5029-4669...   99.842476
# 20  [{'Type': 'CHILD', 'Ids': ['f37e4664-6439-437b...   81.065613
# 21  [{'Type': 'CHILD', 'Ids': ['394a93dd-a5c8-4f06...   98.580238
# 22  [{'Type': 'CHILD', 'Ids': ['076146c8-d982-4032...   80.704796
# 23  [{'Type': 'CHILD', 'Ids': ['fd4dd623-36ea-44af...   96.991760
# 24  [{'Type': 'CHILD', 'Ids': ['1457e5ff-efbe-485f...   85.701813
# 25  [{'Type': 'CHILD', 'Ids': ['4336d5ad-3210-4b8d...   99.509460
# 26  [{'Type': 'CHILD', 'Ids': ['4cd9cc0d-9ac2-4291...   61.051453
# 27  [{'Type': 'CHILD', 'Ids': ['dc76d88e-1b9e-4eeb...   76.653297
# 28  [{'Type': 'CHILD', 'Ids': ['05f44657-f3ba-4d29...   99.512207
# 29  [{'Type': 'CHILD', 'Ids': ['f9973c15-9e20-41f9...   80.177132
# 30  [{'Type': 'CHILD', 'Ids': ['8e8c15d5-05af-4fe0...   94.062630
# 31  [{'Type': 'CHILD', 'Ids': ['3adfc146-8798-4545...   97.919563
# 32  [{'Type': 'CHILD', 'Ids': ['ece8ed83-f825-4e85...   54.634678
# 33  [{'Type': 'CHILD', 'Ids': ['2f4374f7-94d7-4f4e...   70.721977
# 34  [{'Type': 'CHILD', 'Ids': ['4f5478cb-65a3-4d74...   78.191734
# 35  [{'Type': 'CHILD', 'Ids': ['a400ae0b-c36d-4c00...   97.789909
# 36  [{'Type': 'CHILD', 'Ids': ['3d71e8f6-7ba6-480b...   75.197426
# 37  [{'Type': 'CHILD', 'Ids': ['12b109d4-06d4-4661...   79.678902
# 38  [{'Type': 'CHILD', 'Ids': ['bdef7b9b-d00a-4af5...   98.164734
# 39  [{'Type': 'CHILD', 'Ids': ['c0c18cef-1f3a-4a0a...   99.027290
# 40  [{'Type': 'CHILD', 'Ids': ['15338d9c-e5c0-4e55...   60.945660
# 41  [{'Type': 'CHILD', 'Ids': ['4fead2a8-8239-4acc...   98.908638
# 42  [{'Type': 'CHILD', 'Ids': ['eea70ca2-64e5-4630...   84.800209
# 43  [{'Type': 'CHILD', 'Ids': ['b5cf4598-6702-4ae1...   98.781715
# 44  [{'Type': 'CHILD', 'Ids': ['f128aa9c-9225-425e...   88.216606
# 45  [{'Type': 'CHILD', 'Ids': ['a9ad0abb-2e55-44c4...   78.389351
# 46  [{'Type': 'CHILD', 'Ids': ['3a881cdf-8794-49ed...   75.208443
# 47  [{'Type': 'CHILD', 'Ids': ['c4faaf02-6d3c-4eef...   83.572182
# 48  [{'Type': 'CHILD', 'Ids': ['7a578678-1f98-4b4b...   93.949631
# 49  [{'Type': 'CHILD', 'Ids': ['2f42b416-35c2-4898...   90.749588
# 50  [{'Type': 'CHILD', 'Ids': ['b3c73947-306a-4c30...   63.699894
#
#                                        Text EntityTypes
# 1                                         N         NaN
# 2                 FACTURA DE CREDITO FISCAL         NaN
# 3                     latienda de La fabric         NaN
# 4                            by el papelito         NaN
# 5                          NCF: B0100108041         NaN
# 6                    Industrias Nigua, S.A.         NaN
# 7                   VALIDO HASTA 31/12/2020         NaN
# 8                            RNC: 101004851         NaN
# 9                           NCF MODOFICADO:         NaN
# 10  Av. San Cristobal No. 2, Ensanche la Fe         NaN
# 11        Santo domingo (Distrito naclonal)         NaN
# 12       LA EMPANADERIA SABOR MUNDO CULTURA         NaN
# 13                               NO FACTURA         NaN
# 14                                      RNC         NaN
# 15                                    FECHA         NaN
# 16       C GLADYS NIVARA #3A, LA CASTELLANA         NaN
# 17                                AALF/ 150         NaN
# 18                                132028732         NaN
# 19                                5/18/2020         NaN
# 20                     Distrito nacional ()         NaN
# 21                      REFERENCIA CANTIDAD         NaN
# 22                              DESCRIPCION         NaN
# 23                                   PRECIO         NaN
# 24                                      DTO         NaN
# 25                                  IMPORTE         NaN
# 26                                   PYA049         NaN
# 27       NE Albarin A1H/147 Fecha 5/18/2020         NaN
# 28                                        4         NaN
# 29      11270 ENV PLAST NIGRO SOUFFL C2 20/         NaN
# 30                                    83.05         NaN
# 31                                   332.20         NaN
# 32                                    PE05O         NaN
# 33    300 FUNDA 2SK GEN S/ASA 0.1 ML 42x10A         NaN
# 34                                      5A2         NaN
# 35                                   162712         NaN
# 36                                   PHEDOT         NaN
# 37         6 TOALLA P/COCINA A GRANEL NIVED         NaN
# 38                                    63.56         NaN
# 39                                   381 36         NaN
# 40                                   PSCOOS         NaN
# 41                                       11         NaN
# 42                 SERV DISP CAVIOTA 10/300         NaN
# 43                                    46.61         NaN
# 44                                   512.71         NaN
# 45                                    PKADS         NaN
# 46                                        6         NaN
# 47       18092 TAPA P/ENVASES SOUFFLES 20/1         NaN
# 48                                     83.0         NaN
# 49                                   498.31         NaN
# 50                                  DLLVERY         NaN

# %%
lines = [b for b in blocks if b["BlockType"] == "LINE"]

# %%
words = [b for b in blocks if b["BlockType"] == "WORD"]

# %%
kv = [b for b in blocks if b["BlockType"] == "KEY_VALUE_SET"]

# %%
response
# Out:
# {'DocumentMetadata': {'Pages': 1},
#  'Blocks': [{'BlockType': 'PAGE',
#    'Geometry': {'BoundingBox': {'Width': 1.0,
#      'Height': 1.0,
#      'Left': 0.0,
#      'Top': 0.0},
#     'Polygon': [{'X': 0.0, 'Y': 0.0},
#      {'X': 1.0, 'Y': 0.0},
#      {'X': 1.0, 'Y': 1.0},
#      {'X': 0.0, 'Y': 1.0}]},
#    'Id': 'fe9a50b5-87d2-44eb-a5a9-a8c57a227c9f',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['72d9d33e-1937-4e90-8445-985c41ecf265',
#       '03115951-50bc-48d4-af49-1d6ee1ba52e5',
#       '7ce91950-e374-4837-ad80-f294f5cc5737',
#       '7f7f4e2d-d90e-4d1f-a71f-89e767adee8d',
#       '65ba8b68-37f3-4e9f-baae-d936dde4e53b',
#       'c4792abc-9279-4f45-9253-5f7bf1f0f459',
#       '40e23ef2-e0c8-4863-b645-4a85584c067d',
#       '44478e7b-639d-4724-8eaa-76b01a578da9',
#       '6a2dba5d-9361-4ea0-90d7-406915ef588c',
#       '90359c32-a90d-49ea-8d32-beb50450e8f2',
#       'f388eb62-69ee-4f78-84a9-0bd87b4df565',
#       '2751d7cc-4f90-4ef6-a55b-ef4208a7af4b',
#       '79b0aa23-b356-4b3b-aabe-c114d3cb9edc',
#       '3d24886f-7f20-4cf6-b61b-8d6588f2fd42',
#       '23620c7e-4e96-44a6-9e13-acae78da00b7',
#       '30742ab3-3728-40f5-b869-17cd77074b50',
#       '9c3f9e81-99ea-4cc7-b181-b9cee5a54959',
#       'c3b009c5-5f1b-4231-b6c9-728e6c92ef23',
#       '3be5b07e-bd45-4dd3-a59a-4a5144de1ce4',
#       '872fb21d-73b1-4b95-a43a-46065c9e26d5',
#       '3882f160-ee11-497c-bd43-e5414a3e27ce',
#       '084c4f48-68ef-4900-9de9-4404174c5749',
#       '3d289a40-9d95-4b7c-b3b4-a6a35ac288bf',
}]},
#   {'BlockType': 'LINE',
#    'Confidence': 97.8615951538086,
#    'Text': 'NETO',
#    'Geometry': {'BoundingBox': {'Width': 0.04112851619720459,
#      'Height': 0.008656799793243408,
#      'Left': 0.8674514889717102,
#      'Top': 0.7514374256134033},
#     'Polygon': [{'X': 0.8674514889717102, 'Y': 0.7514374256134033},
#      {'X': 0.9085800051689148, 'Y': 0.7514374256134033},
#      {'X': 0.9085800051689148, 'Y': 0.7600942254066467},
#      {'X': 0.8674514889717102, 'Y': 0.7600942254066467}]},
#    'Id': '76f89c77-032a-4645-98a3-320874cd90ae',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['90af3952-df37-4502-a47b-c6179290e700']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 93.33192443847656,
#    'Text': 'IMP ITBIS',
#    'Geometry': {'BoundingBox': {'Width': 0.07145821303129196,
#      'Height': 0.009979017078876495,
#      'Left': 0.5572691559791565,
#      'Top': 0.7604155540466309},
#     'Polygon': [{'X': 0.5572691559791565, 'Y': 0.7604155540466309},
#      {'X': 0.628727376461029, 'Y': 0.7604155540466309},
#      {'X': 0.628727376461029, 'Y': 0.7703945636749268},
#      {'X': 0.5572691559791565, 'Y': 0.7703945636749268}]},
#    'Id': 'ab32fdd5-f0bf-4f34-93ca-b3edf199f014',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['d1bbb165-d9ad-4839-b7f6-f3cc63368c38',
#       'd8d6b7d9-7230-4b82-a400-e7280f2caf88']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 91.34972381591797,
#    'Text': 'B.955 00',
#    'Geometry': {'BoundingBox': {'Width': 0.05134904384613037,
#      'Height': 0.00868070125579834,
#      'Left': 0.8809491395950317,
#      'Top': 0.7658818960189819},
#     'Polygon': [{'X': 0.8809491395950317, 'Y': 0.7658818960189819},
#      {'X': 0.9322981834411621, 'Y': 0.7658818960189819},
#      {'X': 0.9322981834411621, 'Y': 0.7745625972747803},
#      {'X': 0.8809491395950317, 'Y': 0.7745625972747803}]},
#    'Id': '16cadff9-790d-4b2b-8dec-a50fe3b34e87',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['713f455f-3208-422f-b8f5-71f134568a33']}]},
#   {'BlockType': 'LINE',
#    'Confidence': 89.17460632324219,
#    'Text': '3.351.69',
#    'Geometry': {'BoundingBox': {'Width': 0.04809579253196716,
#      'Height': 0.008859813213348389,
#      'Left': 0.4238079786300659,
#      'Top': 0.7768577933311462},
#     'Polygon': [{'X': 0.4238079786300659, 'Y': 0.7768577933311462},
# ...
#    'Id': '8525b9e5-385d-4dfa-b40f-75eebce3389c'},
#   {'BlockType': 'WORD',
#    'Confidence': 53.26563262939453,
#    'Text': 'Ta',
#    'Geometry': {'BoundingBox': {'Width': 0.010472170077264309,
#      'Height': 0.007919699884951115,
#      'Left': 0.5168482661247253,
#      'Top': 0.9102004170417786},
#     'Polygon': [{'X': 0.5168482661247253, 'Y': 0.9102004170417786},
#      {'X': 0.5273204445838928, 'Y': 0.9102004170417786},
#      {'X': 0.5273204445838928, 'Y': 0.9181200861930847},
#      {'X': 0.5168482661247253, 'Y': 0.9181200861930847}]},
#    'Id': '295ef544-c84d-4b97-8b24-7e5b10c8aca5'},
#   {'BlockType': 'WORD',
#    'Confidence': 94.4365463256836,
#    'Text': 'Fe',
#    'Geometry': {'BoundingBox': {'Width': 0.015956340357661247,
#      'Height': 0.00791895017027855,
#      'Left': 0.5293301939964294,
#      'Top': 0.9104094505310059},
#     'Polygon': [{'X': 0.5293301939964294, 'Y': 0.9104094505310059},
#      {'X': 0.5452865362167358, 'Y': 0.9104094505310059},
#      {'X': 0.5452865362167358, 'Y': 0.9183284044265747},
#      {'X': 0.5293301939964294, 'Y': 0.9183284044265747}]},
#    'Id': 'afc73e7c-4b64-4ed9-82b9-d99b489d2674'},
#   {'BlockType': 'WORD',
#    'Confidence': 80.67840576171875,
#    'Text': 'Santo',
#    'Geometry': {'BoundingBox': {'Width': 0.03689249977469444,
#      'Height': 0.008742869831621647,
#      'Left': 0.54966801404953,
#      'Top': 0.9087105989456177},
#     'Polygon': [{'X': 0.54966801404953, 'Y': 0.9087105989456177},
#      {'X': 0.5865604877471924, 'Y': 0.9087105989456177},
#      {'X': 0.5865604877471924, 'Y': 0.9174534678459167},
#      {'X': 0.54966801404953, 'Y': 0.9174534678459167}]},
#    'Id': '36242fd4-4bd3-4710-9d5e-8b48c2179718'},
#   {'BlockType': 'WORD',
#    'Confidence': 98.55620574951172,
#    'Text': 'domingo',
#    'Geometry': {'BoundingBox': {'Width': 0.05386773869395256,
#      'Height': 0.01070920005440712,
#      'Left': 0.5881624817848206,
#      'Top': 0.9056037068367004},
#     'Polygon': [{'X': 0.5881624817848206, 'Y': 0.9056037068367004},
#      {'X': 0.6420302391052246, 'Y': 0.9056037068367004},
#      {'X': 0.6420302391052246, 'Y': 0.9163128733634949},
#      {'X': 0.5881624817848206, 'Y': 0.9163128733634949}]},
#    'Id': 'd376cb8e-479c-4d19-8f4c-2824784ab5a4'},
#   {'BlockType': 'WORD',
#    'Confidence': 88.84043884277344,
#    'Text': '(Distrito',
#    'Geometry': {'BoundingBox': {'Width': 0.050484128296375275,
#      'Height': 0.010778269730508327,
#      'Left': 0.6435306668281555,
#      'Top': 0.9038593173027039},
#     'Polygon': [{'X': 0.6435306668281555, 'Y': 0.9038593173027039},
#      {'X': 0.6940147876739502, 'Y': 0.9038593173027039},
#      {'X': 0.6940147876739502, 'Y': 0.914637565612793},
#      {'X': 0.6435306668281555, 'Y': 0.914637565612793}]},
#    'Id': 'f76f8c2f-043e-4da1-8d5a-14b5464674b4'},
#   {'BlockType': 'WORD',
#    'Confidence': 94.90705108642578,
#    'Text': 'nacionall',
#    'Geometry': {'BoundingBox': {'Width': 0.05947503075003624,
#      'Height': 0.010147700086236,
#      'Left': 0.6957908272743225,
#      'Top': 0.9011853933334351},
#     'Polygon': [{'X': 0.6957908272743225, 'Y': 0.9011853933334351},
#      {'X': 0.7552658319473267, 'Y': 0.9011853933334351},
#      {'X': 0.7552658319473267, 'Y': 0.9113330841064453},
#      {'X': 0.6957908272743225, 'Y': 0.9113330841064453}]},
#    'Id': '12d00d15-fee9-45cc-97c6-cd4c13ec03a0'},
#   {'BlockType': 'WORD',
#    'Confidence': 85.91068267822266,
#    'Text': 'E-mail:',
#    'Geometry': {'BoundingBox': {'Width': 0.04576690122485161,
#      'Height': 0.009916500188410282,
#      'Left': 0.7160845994949341,
#      'Top': 0.916847825050354},
#     'Polygon': [{'X': 0.7160845994949341, 'Y': 0.916847825050354},
#      {'X': 0.7618514895439148, 'Y': 0.916847825050354},
#      {'X': 0.7618514895439148, 'Y': 0.9267643094062805},
#      {'X': 0.7160845994949341, 'Y': 0.9267643094062805}]},
#    'Id': 'd8cb0bc8-8649-42ea-8fd9-69ff9641c3ca'},
#   {'BlockType': 'WORD',
#    'Confidence': 87.62132263183594,
#    'Text': '1/1',
#    'Geometry': {'BoundingBox': {'Width': 0.02751689963042736,
#      'Height': 0.00937649980187416,
#      'Left': 0.9509783983230591,
#      'Top': 0.9044489860534668},
#     'Polygon': [{'X': 0.9509783983230591, 'Y': 0.9044489860534668},
#      {'X': 0.9784952998161316, 'Y': 0.9044489860534668},
#      {'X': 0.9784952998161316, 'Y': 0.913825511932373},
#      {'X': 0.9509783983230591, 'Y': 0.913825511932373}]},
#    'Id': '42fea3d3-87f8-491e-ab3b-d4ec86e6ba9e'},
#   {'BlockType': 'WORD',
#    'Confidence': 84.62821960449219,
#    'Text': 'RNC:',
#    'Geometry': {'BoundingBox': {'Width': 0.034066300839185715,
#      'Height': 0.009358029812574387,
#      'Left': 0.16777966916561127,
#      'Top': 0.9326599836349487},
#     'Polygon': [{'X': 0.16777966916561127, 'Y': 0.9326599836349487},
#      {'X': 0.20184597373008728, 'Y': 0.9326599836349487},
#      {'X': 0.20184597373008728, 'Y': 0.9420180320739746},
#      {'X': 0.16777966916561127, 'Y': 0.9420180320739746}]},
#    'Id': '695b701f-4030-4e49-a9ab-96fe1267eb91'},
#   {'BlockType': 'WORD',
#    'Confidence': 99.63531494140625,
#    'Text': '101004851',
#    'Geometry': {'BoundingBox': {'Width': 0.07593107223510742,
#      'Height': 0.011308839544653893,
#      'Left': 0.20438268780708313,
#      'Top': 0.9295350909233093},
#     'Polygon': [{'X': 0.20438268780708313, 'Y': 0.9295350909233093},
#      {'X': 0.28031376004219055, 'Y': 0.9295350909233093},
#      {'X': 0.28031376004219055, 'Y': 0.940843939781189},
#      {'X': 0.20438268780708313, 'Y': 0.940843939781189}]},
#    'Id': 'b4f12e8f-eb1f-46f2-afa2-c1476354ffdb'},
#   {'BlockType': 'WORD',
#    'Confidence': 87.61678314208984,
#    'Text': 'Telefono:',
#    'Geometry': {'BoundingBox': {'Width': 0.06402856111526489,
#      'Height': 0.010126099921762943,
#      'Left': 0.288793683052063,
#      'Top': 0.9276230931282043},
#     'Polygon': [{'X': 0.288793683052063, 'Y': 0.9276230931282043},
#      {'X': 0.3528222441673279, 'Y': 0.9276230931282043},
#      {'X': 0.3528222441673279, 'Y': 0.9377492070198059},
#      {'X': 0.288793683052063, 'Y': 0.9377492070198059}]},
#    'Id': '6f65e3fc-0d17-463a-9ba7-69073015facb'},
#   {'BlockType': 'WORD',
#    'Confidence': 93.12593078613281,
#    'Text': '(809',
#    'Geometry': {'BoundingBox': {'Width': 0.034604430198669434,
#      'Height': 0.011187559925019741,
#      'Left': 0.35423174500465393,
#      'Top': 0.9268819093704224},
#     'Polygon': [{'X': 0.35423174500465393, 'Y': 0.9268819093704224},
#      {'X': 0.38883617520332336, 'Y': 0.9268819093704224},
#      {'X': 0.38883617520332336, 'Y': 0.9380694627761841},
#      {'X': 0.35423174500465393, 'Y': 0.9380694627761841}]},
#    'Id': '125fb688-ffa7-44a2-b491-fc87f0c01b02'},
#   {'BlockType': 'WORD',
#    'Confidence': 97.18126678466797,
#    'Text': '565-5518',
#    'Geometry': {'BoundingBox': {'Width': 0.06162431091070175,
#      'Height': 0.01020164042711258,
#      'Left': 0.3880913257598877,
#      'Top': 0.9259262084960938},
#     'Polygon': [{'X': 0.3880913257598877, 'Y': 0.9259262084960938},
#      {'X': 0.44971564412117004, 'Y': 0.9259262084960938},
#      {'X': 0.44971564412117004, 'Y': 0.9361278414726257},
#      {'X': 0.3880913257598877, 'Y': 0.9361278414726257}]},
#    'Id': '04f38730-5631-4cf2-ad55-2aaa22ce3904'},
#   {'BlockType': 'WORD',
#    'Confidence': 99.16941833496094,
#    'Text': 'Sitio',
#    'Geometry': {'BoundingBox': {'Width': 0.026321260258555412,
#      'Height': 0.008858130313456059,
#      'Left': 0.45717793703079224,
#      'Top': 0.9258934855461121},
#     'Polygon': [{'X': 0.45717793703079224, 'Y': 0.9258934855461121},
#      {'X': 0.4834991991519928, 'Y': 0.9258934855461121},
#      {'X': 0.4834991991519928, 'Y': 0.9347516298294067},
#      {'X': 0.45717793703079224, 'Y': 0.9347516298294067}]},
#    'Id': '7fe477b7-4b0e-41e5-939e-a576ffce07a9'},
#   {'BlockType': 'WORD',
#    'Confidence': 98.77259063720703,
#    'Text': 'Web',
#    'Geometry': {'BoundingBox': {'Width': 0.027640879154205322,
#      'Height': 0.008622800000011921,
#      'Left': 0.4840191602706909,
#      'Top': 0.9260780215263367},
#     'Polygon': [{'X': 0.4840191602706909, 'Y': 0.9260780215263367},
#      {'X': 0.5116600394248962, 'Y': 0.9260780215263367},
#      {'X': 0.5116600394248962, 'Y': 0.9347007870674133},
#      {'X': 0.4840191602706909, 'Y': 0.9347007870674133}]},
#    'Id': 'a9b4a512-e9b0-4062-97fd-1e3b6e7a853d'},
#   {'BlockType': 'WORD',
#    'Confidence': 85.1418228149414,
#    'Text': 'www.latiendadelafabrica.com.do',
#    'Geometry': {'BoundingBox': {'Width': 0.196110799908638,
#      'Height': 0.016186119988560677,
#      'Left': 0.5128862261772156,
#      'Top': 0.9190333485603333},
#     'Polygon': [{'X': 0.5128862261772156, 'Y': 0.9190333485603333},
#      {'X': 0.7089970111846924, 'Y': 0.9190333485603333},
#      {'X': 0.7089970111846924, 'Y': 0.9352194666862488},
#      {'X': 0.5128862261772156, 'Y': 0.9352194666862488}]},
#    'Id': 'b29730e0-128b-413e-b649-e5f4699c7975'},
#   {'BlockType': 'KEY_VALUE_SET',
#    'Confidence': 59.53736877441406,
#    'Geometry': {'BoundingBox': {'Width': 0.0840040072798729,
#      'Height': 0.01016843318939209,
#      'Left': 0.1015927717089653,
#      'Top': 0.3615715503692627},
#     'Polygon': [{'X': 0.1015927717089653, 'Y': 0.3615715503692627},
#      {'X': 0.1855967789888382, 'Y': 0.3615715503692627},
#      {'X': 0.1855967789888382, 'Y': 0.3717399835586548},
#      {'X': 0.1015927717089653, 'Y': 0.3717399835586548}]},
#    'Id': 'ae77a6bf-703e-4a57-a079-20aafc9d69d6',
#    'Relationships': [{'Type': 'VALUE',
#      'Ids': ['79497444-de58-46d4-81f7-01a3cc752840']},
#     {'Type': 'CHILD',
#      'Ids': ['539ea562-fc4c-44df-bcbd-32987f0401f2',
#       'df26a36a-21d2-4311-9594-ca54f895dd58']}],
#    'EntityTypes': ['KEY']},
#   {'BlockType': 'KEY_VALUE_SET',
#    'Confidence': 59.53736877441406,
#    'Geometry': {'BoundingBox': {'Width': 0.07855788618326187,
#      'Height': 0.01032116450369358,
#      'Left': 0.09415511786937714,
#      'Top': 0.3833267092704773},
#     'Polygon': [{'X': 0.09415511786937714, 'Y': 0.3833267092704773},
#      {'X': 0.1727130115032196, 'Y': 0.3833267092704773},
#      {'X': 0.1727130115032196, 'Y': 0.39364784955978394},
#      {'X': 0.09415511786937714, 'Y': 0.39364784955978394}]},
#    'Id': '79497444-de58-46d4-81f7-01a3cc752840',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['b5e3b466-6509-467a-a2e9-2be335256570',
#       'a58e22af-3f4d-401b-8403-9ec37a8fc3c1']}],
#    'EntityTypes': ['VALUE']},
#   {'BlockType': 'KEY_VALUE_SET',
#    'Confidence': 47.85462951660156,
#    'Geometry': {'BoundingBox': {'Width': 0.04558669030666351,
#      'Height': 0.010494112968444824,
#      'Left': 0.3804105222225189,
#      'Top': 0.3684617280960083},
#     'Polygon': [{'X': 0.3804105222225189, 'Y': 0.3684617280960083},
#      {'X': 0.42599719762802124, 'Y': 0.3684617280960083},
#      {'X': 0.42599719762802124, 'Y': 0.3789558410644531},
#      {'X': 0.3804105222225189, 'Y': 0.3789558410644531}]},
#    'Id': '58356817-dffc-4923-9280-df1cb805c193',
#    'Relationships': [{'Type': 'VALUE',
#      'Ids': ['d8d14938-22b0-414e-b280-eb72dc8232a3']},
#     {'Type': 'CHILD', 'Ids': ['c32df702-4ad1-44b5-881b-9fcf0f030dc0']}],
#    'EntityTypes': ['KEY']},
#   {'BlockType': 'KEY_VALUE_SET',
#    'Confidence': 47.85462951660156,
#    'Geometry': {'BoundingBox': {'Width': 0.06969587504863739,
#      'Height': 0.011014008894562721,
#      'Left': 0.3610546588897705,
#      'Top': 0.3887840509414673},
#     'Polygon': [{'X': 0.3610546588897705, 'Y': 0.3887840509414673},
#      {'X': 0.4307505190372467, 'Y': 0.3887840509414673},
#      {'X': 0.4307505190372467, 'Y': 0.39979806542396545},
#      {'X': 0.3610546588897705, 'Y': 0.39979806542396545}]},
#    'Id': 'd8d14938-22b0-414e-b280-eb72dc8232a3',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['0daf0717-5029-4669-8c03-e5334c7f243a']}],
#    'EntityTypes': ['VALUE']},
#   {'BlockType': 'KEY_VALUE_SET',
#    'Confidence': 41.73244094848633,
#    'Geometry': {'BoundingBox': {'Width': 0.03189649432897568,
#      'Height': 0.008765602484345436,
#      'Left': 0.16906355321407318,
#      'Top': 0.933071494102478},
#     'Polygon': [{'X': 0.16906355321407318, 'Y': 0.933071494102478},
#      {'X': 0.20096005499362946, 'Y': 0.933071494102478},
#      {'X': 0.20096005499362946, 'Y': 0.9418371319770813},
#      {'X': 0.16906355321407318, 'Y': 0.9418371319770813}]},
#    'Id': 'c4ff3d80-3f25-47ac-8235-0a0fc49f8e77',
#    'Relationships': [{'Type': 'VALUE',
#      'Ids': ['8c0e46e0-9ed3-4243-9875-a6c754af25cf']},
#     {'Type': 'CHILD', 'Ids': ['695b701f-4030-4e49-a9ab-96fe1267eb91']}],
#    'EntityTypes': ['KEY']},
#   {'BlockType': 'KEY_VALUE_SET',
#    'Confidence': 41.73244094848633,
#    'Geometry': {'BoundingBox': {'Width': 0.027426740154623985,
#      'Height': 0.009035015478730202,
#      'Left': 0.9517940282821655,
#      'Top': 0.9053467512130737},
#     'Polygon': [{'X': 0.9517940282821655, 'Y': 0.9053467512130737},
#      {'X': 0.9792207479476929, 'Y': 0.9053467512130737},
#      {'X': 0.9792207479476929, 'Y': 0.9143818020820618},
#      {'X': 0.9517940282821655, 'Y': 0.9143818020820618}]},
#    'Id': '8c0e46e0-9ed3-4243-9875-a6c754af25cf',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['42fea3d3-87f8-491e-ab3b-d4ec86e6ba9e']}],
#    'EntityTypes': ['VALUE']},
#   {'BlockType': 'KEY_VALUE_SET',
#    'Confidence': 36.3808479309082,
#    'Geometry': {'BoundingBox': {'Width': 0.06722420454025269,
#      'Height': 0.009211445227265358,
#      'Left': 0.27926239371299744,
#      'Top': 0.7621791958808899},
#     'Polygon': [{'X': 0.27926239371299744, 'Y': 0.7621791958808899},
#      {'X': 0.3464865982532501, 'Y': 0.7621791958808899},
#      {'X': 0.3464865982532501, 'Y': 0.7713906168937683},
#      {'X': 0.27926239371299744, 'Y': 0.7713906168937683}]},
#    'Id': 'e69be1c3-ba2b-43ca-8c04-958cf3bb0a5a',
#    'Relationships': [{'Type': 'VALUE',
#      'Ids': ['129f7918-8620-4d8d-84aa-fd99ae9b2673']},
#     {'Type': 'CHILD',
#      'Ids': ['3efd4622-1d84-4b9f-99a0-50d6634e23b9',
#       '28cf87a4-6a53-4f0a-95a3-9fca97817cea']}],
#    'EntityTypes': ['KEY']},
#   {'BlockType': 'KEY_VALUE_SET',
#    'Confidence': 36.3808479309082,
#    'Geometry': {'BoundingBox': {'Width': 0.08409015089273453,
#      'Height': 0.046066999435424805,
#      'Left': 0.2704814672470093,
#      'Top': 0.7777923941612244},
#     'Polygon': [{'X': 0.2704814672470093, 'Y': 0.7777923941612244},
#      {'X': 0.3545716106891632, 'Y': 0.7777923941612244},
#      {'X': 0.3545716106891632, 'Y': 0.8238593935966492},
#      {'X': 0.2704814672470093, 'Y': 0.8238593935966492}]},
#    'Id': '129f7918-8620-4d8d-84aa-fd99ae9b2673',
#    'EntityTypes': ['VALUE']},
#   {'BlockType': 'KEY_VALUE_SET',
#    'Confidence': 40.8317756652832,
#    'Geometry': {'BoundingBox': {'Width': 0.02912968583405018,
#      'Height': 0.009101653471589088,
#      'Left': 0.2646379768848419,
#      'Top': 0.36547428369522095},
#     'Polygon': [{'X': 0.2646379768848419, 'Y': 0.36547428369522095},
#      {'X': 0.29376766085624695, 'Y': 0.36547428369522095},
#      {'X': 0.29376766085624695, 'Y': 0.3745759427547455},
#      {'X': 0.2646379768848419, 'Y': 0.3745759427547455}]},
#    'Id': '2ee0e754-69a6-44b8-b348-eaa7b2021d48',
#    'Relationships': [{'Type': 'VALUE',
#      'Ids': ['a6e7fa2c-3eae-4af1-9cca-4355ab0c8376']},
#     {'Type': 'CHILD', 'Ids': ['2baadebd-62d4-4ce1-8859-1d1c02697b80']}],
#    'EntityTypes': ['KEY']},
#   {'BlockType': 'KEY_VALUE_SET',
#    'Confidence': 40.8317756652832,
#    'Geometry': {'BoundingBox': {'Width': 0.07737024128437042,
#      'Height': 0.010603475384414196,
#      'Left': 0.2417972981929779,
#      'Top': 0.3862561881542206},
#     'Polygon': [{'X': 0.2417972981929779, 'Y': 0.3862561881542206},
#      {'X': 0.3191675543785095, 'Y': 0.3862561881542206},
#      {'X': 0.3191675543785095, 'Y': 0.39685967564582825},
#      {'X': 0.2417972981929779, 'Y': 0.39685967564582825}]},
#    'Id': 'a6e7fa2c-3eae-4af1-9cca-4355ab0c8376',
#    'Relationships': [{'Type': 'CHILD',
#      'Ids': ['0a1fcb21-1db5-4c77-ac11-f09f7a7f649e']}],
#    'EntityTypes': ['VALUE']}],
#  'AnalyzeDocumentModelVersion': '1.0',
#  'ResponseMetadata': {'RequestId': 'd10c812f-92b5-4fd5-9b11-a4dc6254922c',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'date': 'Sun, 21 Jun 2020 21:40:43 GMT',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '139273',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': 'd10c812f-92b5-4fd5-9b11-a4dc6254922c'},
#   'RetryAttempts': 0}}

# %% [markdown]
# # — DATE

# %%
    
def nearest(items, pivot):
    return min(items, key=lambda x: abs(x - pivot))


def _find_date(text):
    if not text:
        return None
    text = text.lower()
    if 'fecha' in text and len(text) >= 10:
        date = re.findall(r'\d{1,2}/\d{1,2}/\d{2,4}', text)
        if not date:
            date = re.findall(r'\d{1,2}-\d{1,2}-\d{2,4}', text)
        if date:
            date = date[0]
        else:
            date = text.split()[-1]
            if not is_date(date):
                return None
        date = re.sub(r':', '', date)
        date = re.sub(r'\s', '', date)
        if len(date.split("/")) == 3:
#             print("here")
            date = dateutil.parser.parse(date, dayfirst=True)
        elif len(date.split("/")) == 2:
            date = dateutil.parser.parse(date[:2]+"/"+date[3:5]+"/"+"2020", dayfirst=True)
        return date
    elif re.findall(r'\d{1,2}/\d{1,2}/\d{2,4}', text):
        date = re.findall(r'\d{1,2}/\d{1,2}/\d{2,4}', text)
        date = dateutil.parser.parse(date[0], dayfirst=True)
        return date
    elif re.findall(r'\d{1,2}-\d{1,2}-\d{2,4}', text):
        date = re.findall(r'\d{1,2}-\d{1,2}-\d{2,4}', text)
        date = dateutil.parser.parse(date[0], dayfirst=True)
        return date
    else:
        return None
    
def get_date(blocktype):
    date = df.loc[(df.BlockType == blocktype), "Text"].apply(_find_date).dropna().tolist()
    if date:
#         date = [d for d in date if is_date(d)]
        date = [d for d in date if isinstance(d, datetime.datetime)]
        date = [pd.to_datetime(d) for d in date]
        date = nearest(date, datetime.datetime.today())
        date = date.strftime('%Y%m%d')
        print("Date found: {}".format(date))
        return date
    else:
        print("Date NOT found!!!")
        return None

# %%
d = "5/8/2020"

# %%
a = get_date("LINE")
a
# Out:
# Date found: 20200518
# '20200518'

# %%
a = df.loc[(df.BlockType == "LINE"), "Text"].apply(_find_date).dropna()
a
# Out:
# 7    2020-12-31
# 19   2020-05-18
# 27   2020-05-18
# Name: Text, dtype: datetime64[ns]

# %% [markdown]
# # RNC

# %%
re.findall('(?:\d-?){9}$', "FACTURA VALIDA RNC CREDITO 2 131921142 FISCAL")
# Out:
# []

# %%
def _find_rnc(text, outside_rnc_key=False):
    if not text:
        return None
    text = text.lower()
    if 'rnc' in text and len(text) >= 12:
        rnc = re.findall('(?:\d-?){9}$', text)
        if not rnc:
            rnc = re.findall('(?:\d-?){9}', text)
        if rnc:
            rnc = str(rnc[0])
        rnc = re.sub(r':', '', rnc)
        rnc = re.sub(r'\s', '', rnc)
#         rnc = re.sub(r'\s', '', rnc)
        rnc = re.sub(r'-', '', rnc)
        return rnc
    
    elif outside_rnc_key and re.findall('(?:\d-?){9}$', text) and 'ncf' not in text:
        rnc = re.findall('(?:\d-?){9}$', text)
        rnc = re.sub(r'-', '', rnc[0])
        return rnc
#     else:
# #         rnc = re.sub(r'\s', '', text)
#         rnc = re.findall('(?:\d-?){9}$', text)
#         if rnc:
#             rnc = re.sub(r'-', '', rnc[0])
#             return rnc
    else:
        return None

def get_rnc(blocktype):
    rnc_list = df.loc[(df.BlockType == blocktype), "Text"].apply(_find_rnc)\
                                                          .dropna()\
                                                          .drop_duplicates()\
                                                          .tolist()
#     if len(rnc_list) < 2:
#         rnc_list = df.loc[(df.BlockType == blocktype), "Text"].apply(lambda x: _find_rnc(x, True))\
#                                                           .dropna()\
#                                                           .drop_duplicates()\
#                                                           .tolist()
    if rnc_list:
        print("RNC's found: {}".format(rnc_list))
        return rnc_list
    else:
        print("RNC's NOT found!!!")
        return None

# %%
get_rnc("LINE")
# Out:
# RNC's found: ['101004851']
# ['101004851']

# %%
df.loc[(df.BlockType == "LINE"), "Text"].apply(_find_rnc)
# Out:
# 1          None
# 2          None
# 3          None
# 4          None
# 5          None
#         ...
# 75         None
# 76         None
# 77         None
# 78         None
# 79    101004851
# Name: Text, Length: 79, dtype: object

# %% [markdown]
# # — NCF

# %%
a = "B0100031756"

# %%
_find_ncf(a)
# Out:
# 'b0100031756'

# %%
re.findall('B01\d{8}', a)
# Out:
# ['B0100031756']

# %%
def _find_ncf(text):
    if not text:
        return None
    text = text.lower()
    if 'ncf' in text:
        ncf = text.split()[-1]
        ncf = re.sub(r':', '', ncf)
        ncf = re.sub(r'\s', '', ncf)
#         rnc = re.sub(r'\s', '', rnc)
        if re.findall('b01\d{8}', ncf):
            ncf = re.findall('b01\d{8}', ncf)
            ncf = re.sub(r'-', '', ncf[0])
            return ncf
        elif re.findall('01\d{8}', ncf):
            ncf = re.findall('01\d{8}', ncf)
            ncf = 'b' + re.sub(r'-', '', ncf[0])
            return ncf
    elif re.findall('b01\d{8}', text):
#         print("HERE")
        ncf = re.findall('b01\d{8}', text)
        ncf = re.sub(r'-', '', ncf[0])
        return ncf
#     else:
#         return None
#     else:
# #         ncf = re.sub(r'\s', '', text)
#         ncf = re.findall('(?:\d-?){9}$', text)
#         if ncf:
#             ncf = re.sub(r'-', '', ncf[0])
#             return ncf
    else:
        return None

def get_ncf(blocktype):
    ncf = df.loc[(df.BlockType == blocktype), "Text"].apply(_find_ncf).dropna().tolist()
    if ncf:
        ncf = ncf[0].capitalize()
        print("NCF found: {}".format(ncf))
        return ncf
    else:
        print("NCF NOT found!!!")
        return None

# %%
ncf = "NCF: 0000000080100212454"

# %%
re.findall('01\d{8}', ncf)
# Out:
# ['0100212454']

# %%
get_ncf("LINE")
# Out:
# NCF found: B0100108041
# 'B0100108041'

# %%
text = "NCF B0100000072"

# %%
df.loc[(df.BlockType == "LINE"), "Text"].apply(_find_ncf).dropna().tolist()
# Out:
# ['b0100108041']

# %% [markdown]
# # — TOTAL

# %%
def _find_total(amount):
    if not amount:
        return None
    amount = re.findall('[0-9]*,?[0-9]+(?:\.\d{2})', amount)
    if amount:
        return amount[0]
    else:
        return None

def get_total(blocktype):
    total = df.loc[(df.BlockType == blocktype), "Text"].apply(_find_total)\
                                                     .dropna()\
                                                     .drop_duplicates()\
                                                     .tolist()
    if total:
        total = [re.sub(' ', '.', t) for t in total]
        total = [re.sub(',', '', t) for t in total]
        total = list(map(float, total))
        total = max(total)
        print("TOTAL found: {}".format(total))
        return total
    else:
        print("TOTAL NOT found!!!")
        return None

# %%
get_total("LINE")
# Out:
# TOTAL found: 4130.0
# 4130.0

# %%
l = df.loc[(df.BlockType == "LINE"), "Text"].apply(_find_total).dropna().drop_duplicates().tolist()
l
# Out:
# ['83.05',
#  '332.20',
#  '63.56',
#  '46.61',
#  '512.71',
#  '498.31',
#  '175.00',
#  '3.35',
#  '603.31',
#  '4,130.00',
#  '3,526.69']

# %%
df.loc[(df.BlockType == "LINE"), "Text"]
# Out:
# 1                                                     N
# 2                             FACTURA DE CREDITO FISCAL
# 3                                 latienda de La fabric
# 4                                        by el papelito
# 5                                      NCF: B0100108041
#                             ...
# 75                                              CARDNET
# 76                                                    0
# 77    industrias Nigua, SA Av San Cristobal No 2. En...
# 78                                                  1/1
# 79    RNC: 101004851 Telefono: (809 565-5518 Sitio W...
# Name: Text, Length: 79, dtype: object

# %% [markdown]
# # — RESULT

# %%
date = get_date("LINE")
date

rncs = get_rnc("LINE")
rncs

ncf = get_ncf("LINE")
ncf

total = get_total("LINE")
total
# Out:
# Date found: 20200518
# RNC's found: ['101004851']
# NCF found: B0100108041
# TOTAL found: 4130.0
# 4130.0

# %%
# import json
# with open("./rncs_dr_companies.json") as json_file:
#     dr_cos = json.load(json_file)

# %%
receipts = ["recibo1.jpg", "recibo2.jpg", "recibo3.jpg", "recibo4.jpg", "recibo5.jpg",
            "recibo6.jpg", "recibo7.jpg", "recibo8.jpg", "recibo9.jpg"]

# %%
master = pd.DataFrame(columns=["Receipt #", "RNCs", "NCF", "Date", "Total"])
# master.columns = 
# for receipt in receipts:

# %%
import boto3

# Document
s3BucketName = "receipt-parsing-mvp"
documentName = "recibo2.jpg"

# Amazon Textract client
textract = boto3.client('textract')

# Call Amazon Textract — DETECT DOCUMENT TEXT
# response = textract.detect_document_text(
#     Document={
#         'S3Object': {
#             'Bucket': s3BucketName,
#             'Name': documentName
#         }
#     })

# %%
for receipt in receipts:
    # Call Amazon Textract — ANALYZE DOCUMENT
    response = textract.analyze_document(
        Document={
            'S3Object': {
                'Bucket': s3BucketName,
                'Name': receipt
            }
        },
        FeatureTypes=["FORMS"])
    blocks = response["Blocks"]
    df = pd.DataFrame(blocks)
    
    date = get_date("LINE")

    rncs = get_rnc("LINE")

    ncf = get_ncf("LINE")

    total = get_total("LINE")
    
    master = master.append({"Receipt #": receipt,
               "RNCs":str(rncs),
               "NCF":ncf,
               "Date":date,
               "Total":total}, ignore_index=True)
# Out:
# Date found: 20200515
# RNC's found: ['131921142', '132028732']
# NCF found: B0100000072
# TOTAL found: 750.0
# Date NOT found!!!
# RNC's found: ['101068744', '132028732']
# NCF found: B0104743194
# TOTAL found: 1923.8
# Date found: 20200526
# RNC's found: ['101011246', '132028732']
# NCF found: B0100212454
# TOTAL found: 1147.36
# Date found: 20200519
# RNC's found: ['101019921', '132028732']
# NCF found: B0105316356
# TOTAL found: 5995.0
# Date found: 20200518
# RNC's found: ['101004851']
# NCF found: B0100108041
# TOTAL found: 4130.0
# ---------------------------------------------------------------------------
# OutOfBoundsDatetime                       Traceback (most recent call last)
# ~/.pyenv/versions/3.8.0/envs/receipt-parsing/lib/python3.8/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1857         try:
# -> 1858             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    1859             # If tzaware, these values represent unix timestamps, so we
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# pandas/_libs/tslibs/np_datetime.pyx in pandas._libs.tslibs.np_datetime.check_dts_bounds()
#
# OutOfBoundsDatetime: Out of bounds nanosecond timestamp: 7269-01-01 00:00:00
#
# During handling of the above exception, another exception occurred:
#
# OutOfBoundsDatetime                       Traceback (most recent call last)
# <ipython-input-453-c2a1c4e6ebe1> in <module>
#      12     df = pd.DataFrame(blocks)
#      13
# ---> 14     date = get_date("LINE")
#      15
#      16     rncs = get_rnc("LINE")
#
# <ipython-input-388-e4fc4d6cca10> in get_date(blocktype)
#      41 #         date = [d for d in date if is_date(d)]
#      42         date = [d for d in date if isinstance(d, datetime.datetime)]
# ---> 43         date = [pd.to_datetime(d) for d in date]
#      44         date = nearest(date, datetime.datetime.today())
#      45         date = date.strftime('%Y%m%d')
#
# <ipython-input-388-e4fc4d6cca10> in <listcomp>(.0)
#      41 #         date = [d for d in date if is_date(d)]
#      42         date = [d for d in date if isinstance(d, datetime.datetime)]
# ---> 43         date = [pd.to_datetime(d) for d in date]
#      44         date = nearest(date, datetime.datetime.today())
#      45         date = date.strftime('%Y%m%d')
#
# ~/.pyenv/versions/3.8.0/envs/receipt-parsing/lib/python3.8/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     754             result = convert_listlike(arg, format)
#     755     else:
# --> 756         result = convert_listlike(np.array([arg]), format)[0]
#     757
#     758     return result
#
# ~/.pyenv/versions/3.8.0/envs/receipt-parsing/lib/python3.8/site-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     438         assert format is None or infer_datetime_format
#     439         utc = tz == "utc"
# --> 440         result, tz_parsed = objects_to_datetime64ns(
#     441             arg,
#     442             dayfirst=dayfirst,
#
# ~/.pyenv/versions/3.8.0/envs/receipt-parsing/lib/python3.8/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1861             return values.view("i8"), tz_parsed
#    1862         except (ValueError, TypeError):
# -> 1863             raise e
#    1864
#    1865     if tz_parsed is not None:
#
# ~/.pyenv/versions/3.8.0/envs/receipt-parsing/lib/python3.8/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1846
#    1847     try:
# -> 1848         result, tz_parsed = tslib.array_to_datetime(
#    1849             data,
#    1850             errors=errors,
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslibs/np_datetime.pyx in pandas._libs.tslibs.np_datetime.check_dts_bounds()
#
# OutOfBoundsDatetime: Out of bounds nanosecond timestamp: 7269-01-01 00:00:00

# %%
master
# Out:
#      Receipt #                        RNCs          NCF      Date    Total
# 0  recibo1.jpg  ['131921142', '132028732']  B0100000072  20200515   750.00
# 1  recibo2.jpg  ['101068744', '132028732']  B0104743194      None  1923.80
# 2  recibo3.jpg  ['101011246', '132028732']  B0100212454  20200526  1147.36
# 3  recibo4.jpg  ['101019921', '132028732']  B0105316356  20200519  5995.00
# 4  recibo5.jpg               ['101004851']  B0100108041  20200518  4130.00

# %%
master.to_csv('first_trial.txt', sep='|', index=False, header=True)
